# %%
import torch
print(torch.__version__)
print(torch.cuda.is_available())
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
else:
    print("CPU")
# Out:
# 2.7.1+cu118
# True
# NVIDIA GeForce RTX 4060

# %%
import os
import torch

# Kiểm tra xem đang ở đúng thư mục chưa (phải kết thúc bằng yolov7)
print("Thư mục hiện tại:", os.getcwd()) 

# Kiểm tra GPU/CPU
print("Thiết bị:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "CPU")
# Out:
# Thư mục hiện tại: d:\Coding\classroom-detector\classroom-behavior-detection-yolov7
# Thiết bị: NVIDIA GeForce RTX 4060

# %%
# Đảm bảo đang ở trong thư mục yolov7
import os
if os.path.basename(os.getcwd()) != 'yolov7':
    # %cd yolov7

# Chạy lệnh Train
# batch-size 16: RTX 4060 8GB chịu tốt mức này với model Tiny
# workers 0: Bắt buộc cho Windows
# !python train.py --workers 0 --device 0 --batch-size 16 --data ../data.yaml --img 640 640 --cfg cfg/training/yolov7-tiny.yaml --weights yolov7-tiny.pt --name classroom_behavior --hyp data/hyp.scratch.tiny.yaml --epochs 50
# Out:
# d:\Coding\classroom-detector\classroom-behavior-detection-yolov7\yolov7
# wandb: Install Weights & Biases for YOLOR logging with 'pip install wandb' (recommended)
# YOLOR  v0.1-128-ga207844 torch 2.7.1+cu118 CUDA:0 (NVIDIA GeForce RTX 4060, 8187.5MB)
#
# ...

# %%
from IPython.display import Image, display

# Đường dẫn ảnh kết quả (nếu dùng --exist-ok thì nó luôn ở exp)
image_path = 'runs/detect/exp/test1.jpg' 
image_path_2  = 'runs/detect/exp/test2.jpg'

display(Image(filename=image_path))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 7
#       4 image_path = 'runs/detect/exp/test1.jpg'
#       5 image_path_2  = 'runs/detect/exp/test2.jpg'
# ----> 7 display(Image(filename=image_path))
#
# File c:\Users\PC\miniconda3\envs\yolov7\lib\site-packages\IPython\core\display.py:970, in Image.__init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata, alt)
#     968 self.unconfined = unconfined
#     969 self.alt = alt
# --> 970 super(Image, self).__init__(data=data, url=url, filename=filename,
#     971         metadata=metadata)
#     973 if self.width is None and self.metadata.get('width', {}):
#     974     self.width = metadata['width']
#
# File c:\Users\PC\miniconda3\envs\yolov7\lib\site-packages\IPython\core\display.py:327, in DisplayObject.__init__(self, data, url, filename, metadata)
# ...
